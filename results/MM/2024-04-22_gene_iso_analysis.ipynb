# %%
import os
import yaml
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch

from datetime import datetime
from pathlib import Path
from matplotlib.patches import Rectangle

BASE_DIR = Path(os.path.abspath('')).parent.parent
os.chdir(BASE_DIR)
print(f'Working directory: {os.getcwd()}')

from utils import *
# Out:
# Working directory: c:\Users\jespe\Documents\GitHub_local\ARFusion

# %%
with open('config_MM.yaml' ,'r') as file:
    config = yaml.safe_load(file)

ds_NCBI = pd.read_pickle(config['data']['NCBI']['load_path'])
ds_TESSy = pd.read_pickle(config['data']['TESSy']['load_path'])

# %% [markdown]
# # Experiment with systematic removal of genes

# %% [markdown]
# ### Genes in the multimodal dataset

# %%
ds_MM = ds_NCBI[ds_NCBI['num_ab'] > 0].copy()
df_genes = ds_MM[['genotypes', 'num_genotypes']]
df_genes['num_genotypes'].describe()
# Out:
# count    6468.000000
# mean        6.296691
# std         5.065668
# min         1.000000
# 25%         2.000000
# 50%         4.000000
# 75%         9.000000
# max        40.000000
# Name: num_genotypes, dtype: float64

# %%
genotypes = ds_MM['genotypes']
genotypes_exploded = genotypes.explode()
gene_counts = genotypes_exploded.value_counts()
gene_counts.describe()
# Out:
# count     336.000000
# mean      121.211310
# std       444.617562
# min         1.000000
# 25%         1.750000
# 50%         4.500000
# 75%        21.000000
# max      5890.000000
# Name: count, dtype: float64

# %%
unique_genotypes = ds_MM['genotypes'].explode().unique().tolist()
unique_genotypes
# Out:
# ['parC_E84K=POINT',
#  'soxS_A12S=POINT',
#  'blaTEM-1',
#  'parC_S80I=POINT',
#  'gyrA_D87N=POINT',
#  'gyrA_S83L=POINT',
#  'ompC_Q82STOP=POINT',
#  'pmrB_Y358N=POINT',
#  'glpT_E448K=POINT',
#  'parE_S458A=POINT',
#  'blaCTX-M-15',
#  'blaOXA-1',
#  "aac(6')-Ib-cr5",
#  'tet(A)',
#  'aac(3)-VIa',
#  'blaCMY-2',
#  'aadA1',
#  'sul1',
#  'uhpT_E350Q=POINT',
#  'cyaA_S352T=POINT',
#  'parE_I529L=POINT',
#  "aph(3'')-Ib",
#  'blaCTX-M-27',
#  'parC_E84V=POINT',
#  'aph(6)-Id',
#  'aadA5',
#  'sul2',
#  'pmrB_E123D=POINT',
#  'ptsI_V25I=POINT',
#  'mph(A)',
#  'dfrA17',
#  'blaOXA-181',
#  'qnrS1',
#  'dfrA14',
#  'floR',
#  "aph(3')-Ia=PARTIAL_END_OF_CONTIG",
#  'fosA7.5',
#  'tet(M)',
#  'dfrA1',
#  'parE_L416F=POINT',
#  'blaCMY=PARTIAL_END_OF_CONTIG',
#  'ampC_C-42T=POINT',
#  'tet(B)',
#  "aph(3')-Ia",
#  'aac(3)-IId',
#  "aph(3'')-Ib=PARTIAL_END_OF_CONTIG",
#  'qnrB19',
#  'sat2',
#  'aadA2',
#  'dfrA12',
#  'sul2=PARTIAL_END_OF_CONTIG',
#  'qnrB2',
#  'catA1',
#  'dfrA5',
#  'blaTEM=PARTIAL_END_OF_CONTIG',
#  'gyrA_D87G=POINT',
#  'parC_S57T=POINT',
#  "aac(6')-Ib4",
#  'catB3',
#  'parC_E84A=POINT',
#  'gyrA_D87Y=POINT',
#  'tet(A)=PARTIAL_END_OF_CONTIG',
#  'aph(6)-Id=PARTIAL_END_OF_CONTIG',
#  'parC_S80R=POINT',
#  'cmlA1',
#  'sul3',
#  'qnrB6',
#  'tet(D)',
#  'qnrS2',
#  'aadA25',
#  'parC_A56T=POINT',
#  'aadA7',
#  'blaCTX-M-55',
#  'aac(3)-IIe',
#  'catB3=PARTIAL_END_OF_CONTIG',
#  'blaOXA=PARTIAL_END_OF_CONTIG',
#  'dfrA25',
#  'blaTEM-12',
#  'blaCTX-M',
#  'mph(A)=PARTIAL_END_OF_CONTIG',
#  'blaCTX-M-14',
#  'dfrA17=PARTIAL_END_OF_CONTIG',
#  'blaSHV=PARTIAL_END_OF_CONTIG',
#  'blaSHV-12',
#  'marR_S3N=POINT',
#  'erm(B)',
#  'blaCMY-42',
#  'blaTEM-190',
#  'parC_E84G=POINT',
#  "aac(6')-Ib-cr=PARTIAL_END_OF_CONTIG",
#  'nfsA_G126R=POINT',
#  'lnu(G)',
#  'soxR_R20H=POINT',
#  'parE_S458T=POINT',
#  'fosA=PARTIAL_END_OF_CONTIG',
#  'blaTEM-84',
#  'blaTEM-33',
#  'blaCTX-M=PARTIAL_END_OF_CONTIG',
#  'ftsI_N337NYRIN=POINT',
#  'blaTEM-35',
#  'parE_I355T=POINT',
#  'ftsI_I336IKYRI=POINT',
#  'blaKPC-2',
#  "aac(6')-Ib",
#  'ompF_Q88STOP=POINT',
#  'blaKPC-3',
#  'dfrA7',
#  'nfsA_G154E=POINT',
#  "ant(2'')-Ia",
#  'soxR_G121D=POINT',
#  'dfrA36',
#  'blaTEM-135',
#  'nfsA_H11Y=POINT',
#  'blaTEM',
#  'ompC_Q171STOP=POINT',
#  'blaSHV-7',
#  'blaKPC-4',
#  'aac(3)-Ib',
#  'cmlA6',
#  'aac(3)-II=PARTIAL_END_OF_CONTIG',
#  'ampC_T-32A=POINT',
#  'nfsA_R203C=POINT',
#  'blaOXA-9',
#  'blaCTX-M-24',
#  'blaTEMp_C32T=POINT',
#  'dfrA8',
#  'nfsA_Q113STOP=POINT',
#  'blaCTX-M-1',
#  'blaTEM-30',
#  'blaLAP-2',
#  'pmrB_T156M=POINT',
#  'blaCMY-4',
#  'catA2',
#  'qnrB4',
#  'blaDHA-1',
#  'ble',
#  'dfrA4',
#  'dfrA29',
#  'parE_E460D=POINT',
#  'rmtC',
#  'blaCMY-6',
#  "aac(6')-Ib3",
#  'blaNDM-1',
#  'blaOXA-2',
#  'catA1=PARTIAL_END_OF_CONTIG',
#  'mcr-1.1',
#  "aac(6')-Ib'",
#  'arr-3',
#  'blaNDM-9',
#  'blaCTX-M-65',
#  'fosA3',
#  'blaNDM-7',
#  'blaTEM-20',
#  'blaNDM-5',
#  'blaNDM-6',
#  "aph(3')-VI",
#  'lnu(F)',
#  'blaCTX-M-8',
#  'nfsB_F84S=POINT',
#  "aph(3')-IIa",
#  'blaOXA-232',
#  'aadA22',
#  'mcr-3.1',
#  'mef(B)',
#  'aac(3)-VIa=PARTIAL_END_OF_CONTIG',
#  'bleO',
#  'mcr-3.2',
#  'aadA1=PARTIAL_END_OF_CONTIG',
#  'mcr-3.5',
#  'tet(X4)',
#  'erm(42)',
#  'fosA4',
#  'gyrA_D87H=POINT',
#  'nfsA_Q67STOP=POINT',
#  'oqxA',
#  'oqxB',
#  'blaTEM-103',
#  'mcr-3.24',
#  'fosA5',
#  'ftsI_I336IPYRI=POINT',
#  'aac(3)-IIe=PARTIAL_END_OF_CONTIG',
#  'aph(4)-Ia',
#  'aadA16',
#  'qepA1',
#  'rmtB1',
#  'gyrA_S83V=POINT',
#  'aac(3)-IVa',
#  'dfrA27',
#  'catA3',
#  'qnrB1',
#  'arr-2',
#  'cmlA5',
#  'mph(E)',
#  'msr(E)',
#  'armA',
#  'blaVEB-5',
#  'mph(B)',
#  'mph(G)',
#  'mef(C)',
#  'gyrA_S83A=POINT',
#  'fosA7',
#  'parC_A108V=POINT',
#  'qepA9',
#  'parE_D475E=POINT',
#  'tet(C)',
#  'sul1=PARTIAL_END_OF_CONTIG',
#  'blaHER-3',
#  'blaHER',
#  'blaCARB-2',
#  'dfrA16',
#  'ere(A)',
#  'folP_F28L=POINT',
#  'aph(6)-Ic',
#  'nfsA_W159STOP=POINT',
#  'tet(M)=PARTIAL_END_OF_CONTIG',
#  'estT',
#  'blaCMY',
#  'aadA15',
#  'tet(H)',
#  "aph(3')-IIa=PARTIAL_END_OF_CONTIG",
#  'blaTEM-207',
#  'nfsA_Q44STOP=POINT',
#  'acrR_R45C=POINT',
#  'blaTEM-214',
#  'blaOXA',
#  'blaTEM-40',
#  'parC_A108T=POINT',
#  'blaCTX-M-134',
#  'rpoB_S531F=POINT',
#  'blaPSE',
#  "aac(6')-IIc",
#  'aac(3)-IIg',
#  'arr',
#  'blaHER=PARTIAL_END_OF_CONTIG',
#  'nfsB_W94STOP=POINT',
#  'cmlA1=PARTIAL_END_OF_CONTIG',
#  'aadA6',
#  'qnrA1',
#  'nfsA_R15C=POINT',
#  'blaSCO-1',
#  'blaCTX-M-3',
#  'mcr-10.1',
#  'lnu(C)',
#  'qnrS',
#  'tet(B)=PARTIAL_END_OF_CONTIG',
#  'sul3=PARTIAL_END_OF_CONTIG',
#  'nfsA_G131D=POINT',
#  'acrB_R717L=POINT',
#  'pmrB_C84Y=POINT',
#  'ere(A)=PARTIAL_END_OF_CONTIG',
#  'tet(E)',
#  'aph(4)-Ia=PARTIAL_END_OF_CONTIG',
#  'aac(3)-IVa=PARTIAL_END_OF_CONTIG',
#  'aadA2=PARTIAL_END_OF_CONTIG',
#  'mcr-2.1',
#  'blaSHV',
#  'blaCTX-M-64',
#  'dfrA14=PARTIAL_END_OF_CONTIG',
#  'blaNDM',
#  'ompF_L15STOP=POINT',
#  'blaTEM-19',
#  'dfrA15',
#  'parE_E460K=POINT',
#  'qepA',
#  'blaDHA=PARTIAL_END_OF_CONTIG',
#  'blaCMY-145',
#  'cmlA=PARTIAL_END_OF_CONTIG',
#  'blaTEM-208',
#  "aac(6')-Ib11",
#  'blaOXA-48',
#  'ampC_G-15GG=POINT',
#  'basR_G53R=POINT',
#  'arr=PARTIAL_END_OF_CONTIG',
#  'ampC_C-11T=POINT',
#  'ampC_T-14TGT=POINT',
#  'aadA8',
#  'pmrB_V161G=POINT',
#  'blaCMY-59',
#  'blaTEM-32',
#  'blaTEM-116',
#  'pmrB_P94S=POINT',
#  'blaSHV-1',
#  'blaTEM-52',
#  'qnrB7',
#  'blaCMY-141',
#  'parE_I464F=POINT',
#  'blaTEM-176',
#  'lnu(A)',
#  'aadA15=PARTIAL_END_OF_CONTIG',
#  'parE_L445H=POINT',
#  'qnrB=PARTIAL_END_OF_CONTIG',
#  'dfrB4',
#  'blaTEM-31',
#  'fosA8',
#  'erm(B)=PARTIAL_END_OF_CONTIG',
#  'blaTEM-34',
#  'folP_P64S=POINT',
#  'aac(3)-IId=PARTIAL_END_OF_CONTIG',
#  'pmrB_L10P=POINT',
#  'acrB_R620C=POINT',
#  'marR_R77C=POINT',
#  "aac(2')-IIa",
#  'fabI_F203L=POINT',
#  'pmrB_G206D=POINT',
#  'dfrA23',
#  'blaOXA-10',
#  'qnrS=PARTIAL_END_OF_CONTIG',
#  'blaCTX-M-32',
#  'blaCTX-M-2',
#  "ant(3'')-Ia",
#  'blaSHV-2A',
#  'qnrS13',
#  'lnu(F)=PARTIAL_END_OF_CONTIG',
#  'floR=PARTIAL_END_OF_CONTIG',
#  'blaCTX-M-9',
#  'blaEC-15',
#  'tet(X5)',
#  'tet(G)',
#  'floR2',
#  'blaVEB-1',
#  'blaVIM-1',
#  "aac(6')-Il",
#  "aac(6')-Ib=PARTIAL_END_OF_CONTIG",
#  'blaSHV-5',
#  'blaLAP-1',
#  'qepA4',
#  'blaTEM-57',
#  'blaCTX-M-104',
#  'rpoB_V146F=POINT',
#  'ble=PARTIAL_END_OF_CONTIG',
#  'aadA5=PARTIAL_END_OF_CONTIG',
#  'nfsA_R133S=POINT',
#  'nfsA_K141STOP=POINT',
#  'fosA',
#  'rpoB_H526Y=POINT',
#  'rpoB_Q148L=POINT']

# %% [markdown]
# Using **Reference Gene Catalog** from NCBI to map genotypes to antibiotic class

# %%
pd.set_option('display.max_rows', None)
genotype_ref = pd.read_csv('data/refgenes.tsv', sep='\t')
# genotype_ref = genotype_ref[(genotype_ref['Scope'] == 'core') & (genotype_ref['#Allele'].notna()) & (genotype_ref['Type'] == 'AMR')]
genotype_ref = genotype_ref[(genotype_ref['Scope'] == 'core') & (genotype_ref['Type'] == 'AMR')].reset_index(drop=True)
print(genotype_ref.shape[0])
# Out:
# 8117

# %%
genotype_ref['Subtype'].value_counts()
# Out:
# Subtype
# AMR                6801
# POINT              1290
# AMR-SUSCEPTIBLE      26
# Name: count, dtype: int64

# %%
pm_ref = genotype_ref[genotype_ref['Subtype'] == 'POINT']
gene_ref = genotype_ref[genotype_ref['Subtype'] != 'POINT']
pm_ref.shape[0], gene_ref.shape[0], gene_ref.shape[0]
# Out:
# (1290, 6827, 6827)

# %%
genotype_ref[genotype_ref['Gene family'].str.contains("aac(3)")][['#Allele', 'Gene family']]
# Out:
# C:\Users\jespe\AppData\Local\Temp\ipykernel_15096\66229539.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   genotype_ref[genotype_ref['Gene family'].str.contains("aac(3)")][['#Allele', 'Gene family']]
# Empty DataFrame
# Columns: [#Allele, Gene family]
# Index: []

# %%
genotype_ref['Class'].value_counts()
# Out:
# Class
# BETA-LACTAM                                                       4870
# AMINOGLYCOSIDE                                                     743
# QUINOLONE                                                          465
# COLISTIN                                                           300
# TETRACYCLINE                                                       268
# GLYCOPEPTIDE                                                       234
# TRIMETHOPRIM                                                       142
# PHENICOL                                                           130
# MACROLIDE                                                          127
# RIFAMYCIN                                                          103
# FOSFOMYCIN                                                          92
# LINCOSAMIDE/MACROLIDE/STREPTOGRAMIN                                 80
# FUSIDIC ACID                                                        69
# LIPOPEPTIDE                                                         56
# SULFONAMIDE                                                         56
# PHENICOL/QUINOLONE                                                  43
# LINCOSAMIDE                                                         37
# MULTIDRUG                                                           28
# OXAZOLIDINONE                                                       22
# NITROFURAN                                                          20
# POLYKETIDE                                                          19
# STREPTOGRAMIN                                                       19
# LINCOSAMIDE/MACROLIDE                                               18
# AMINOCOUMARIN                                                       16
# MACROLIDE/STREPTOGRAMIN                                             14
# STREPTOTHRICIN                                                      14
# EFFLUX                                                              13
# LINCOSAMIDE/STREPTOGRAMIN                                           10
# BLEOMYCIN                                                           10
# AMINOGLYCOSIDE/QUINOLONE                                            10
# PHENICOL/LINCOSAMIDE/OXAZOLIDINONE/PLEUROMUTILIN/STREPTOGRAMIN       9
# MUPIROCIN                                                            9
# NITROIMIDAZOLE                                                       9
# ISONIAZID/TRICLOSAN                                                  6
# MACROLIDE/BETA-LACTAM/TETRACYCLINE                                   6
# QUINOLONE/TRICLOSAN                                                  5
# BETA-LACTAM/PHENICOL/QUINOLONE                                       5
# LINCOSAMIDE/PLEUROMUTILIN/STREPTOGRAMIN                              5
# PHENICOL/OXAZOLIDINONE                                               4
# PLEUROMUTILIN                                                        4
# TRICLOSAN                                                            3
# SPIROPYRIMIDINETRIONE                                                3
# TRIMETHOPRIM-SULFAMETHOXAZOLE                                        2
# THIOSTREPTON                                                         2
# BETA-LACTAM/QUINOLONE/TETRACYCLINE                                   2
# AZABICYCLOALKANE                                                     2
# PHENICOL/QUINOLONE/TRIMETHOPRIM                                      1
# BETA-LACTAM/TETRACYCLINE                                             1
# MACROLIDE/OXAZOLIDINONE                                              1
# TETRACENOMYCIN                                                       1
# FOSMIDOMYCIN                                                         1
# EDEINE                                                               1
# LINCOSAMIDE/PLEUROMUTILIN                                            1
# BACITRACIN                                                           1
# AVILAMYCIN                                                           1
# LINCOSAMIDE/OXAZOLIDINONE                                            1
# AMINOGLYCOSIDE/PHENICOL                                              1
# TUBERACTINOMYCIN                                                     1
# FLUOROQUINOLONE                                                      1
# Name: count, dtype: int64

# %%
pm_to_ab_class = pm_ref.set_index('#Allele')['Class'].to_dict()
print(pm_to_ab_class.keys())
gene_to_ab_class = gene_ref.set_index('Gene family')['Class'].to_dict()
print(gene_to_ab_class.keys())
gene_allele_to_ab_class = gene_ref[gene_ref['#Allele'].notna()].set_index('#Allele')['Class'].to_dict()
print(gene_allele_to_ab_class.keys())
# Out:
# dict_keys(['16S_A1055G', '16S_A1408G', '16S_A1499G', '16S_A1519C', '16S_A1519G', '16S_A1519T', '16S_A523C', '16S_A794G', '16S_A794T', '16S_A964G', '16S_C1054T', '16S_C1065T', '16S_C1066T', '16S_C1191T', '16S_C1192A', '16S_C1192G', '16S_C1192T', '16S_C528T', '16S_G1053A', '16S_G1058C', '16S_G1064A', '16S_G1064C', '16S_G1064T', '16S_G1068A', '16S_G527T', '16S_G926A', '16S_G926C', '16S_G926T', '16S_T1406A', '23S_A2045G', '23S_A2057G', '23S_A2058G', '23S_A2058T', '23S_A2074C', '23S_A2074G', '23S_A2074T', '23S_A2075G', '23S_A2114G', '23S_A2115G', '23S_A2118G', '23S_A2145G', '23S_A2531G', '23S_C2220T', '23S_C2579T', '23S_C2597T', '23S_C2611T', '23S_C2627A', '23S_C2630A', '23S_C2630G', '23S_C658T', '23S_G2032A', '23S_G2032C', '23S_G2032T', '23S_G2057A', '23S_G2447T', '23S_G2475T', '23S_G2505A', '23S_G2533A', '23S_G2576T', '23S_G2577T', '23S_G2604T', '23S_G2794T', '23S_T2501A', '23S_T2528A', '23S_T2532C', '23S_T2609C', '23S_T754A', '50S_L22_A103C', '50S_L22_A103V', '50S_L22_A84D', '50S_L22_A88E', '50S_L22_G86E', '50S_L22_G86V', 'acrB_R620C', 'acrB_R717L', 'acrB_R717Q', 'acrR_M109I', 'acrR_R45C', 'acrR_V165I', 'acrR_Y114F', 'adeL_G27R', 'adeR_A91V', 'adeR_D20N', 'adeR_E219A', 'adeR_L192R', 'adeR_P116L', 'adeR_P56S', 'adeS_F12S', 'adeS_G336S', 'adeS_H189Y', 'adeS_I252S', 'adeS_N125K', 'adeS_Q163STOP', 'adeS_R152K', 'adeS_T153M', 'amgS_P381S', 'amgS_R182C', 'amgS_V121G', 'ampC_C-11T', 'ampC_C-42A', 'ampC_C-42G', 'ampC_C-42T', 'ampC_G-15GG', 'ampC_T-14TGT', 'ampC_T-32A', 'ampC_T-32C', 'ampC_T-32G', 'ampD_A18E', 'ampD_E108STOP', 'ampD_E67STOP', 'ampD_F191C', 'ampD_H157Y', 'ampD_H68Y', 'ampD_H74P', 'ampD_H77Y', 'ampD_I121S', 'ampD_L37F', 'ampD_L63P', 'ampD_L75P', 'ampD_P46T', 'ampD_Q155STOP', 'ampD_Q44STOP', 'ampD_R167S', 'ampD_R79G', 'ampD_S120L', 'ampD_S44G', 'ampD_S81P', 'ampD_T139M', 'ampD_V39A', 'ampR_D135G', 'ampR_G154R', 'ampR_R86C', 'amrR_A47T', 'amrR_ASLD153del', 'amrR_E190STOP', 'amrR_E21D', 'amrR_G30D', 'amrR_L132P', 'amrR_L142P', 'amrR_S166P', 'amrR_S174P', 'amrR_VAVC60del', 'arnC_C161Y', 'baeR_S104N', 'baeS_D89V', 'baeS_T175P', 'basR_A80V', 'basR_G15R', 'basR_G53A', 'basR_G53C', 'basR_G53E', 'basR_G53R', 'basR_G53S', 'basR_G53V', 'basR_G53W', 'basR_L105P', 'basR_R81L', 'basR_R81S', 'basR_S39I', 'blaOXA-143_A-14G', 'blaOXA-143_G-42A', 'blaOXA-61_G-57T', 'blaOXY_G-34A', 'blaOXY_G-38T', 'blaOXY_T-58A', 'blaOXY_T-67C', 'blaTEMp_C141G', 'blaTEMp_C32T', 'blaTEMp_G162T', 'bpeR_D176A', 'cdsA_D222N', 'cirA_E133STOP', 'cirA_G75W', 'cirA_R86S', 'cirA_W427STOP', 'cirA_Y253CfsTer5', 'cls_A20D', 'cls_A23V', 'cls_D27N', 'cls_F60S', 'cls_G178T', 'cls_H215R', 'cls_K59T', 'cls_L52F', 'cls_N13I', 'cls_N13T', 'cls_NFQ77del', 'cls_R218Q', 'cls_R267H', 'cls_T33N', 'cmeR_G86A', 'cmrA_A68V', 'cmrA_H204L', 'cmrA_L89Q', 'cmrA_N214K', 'colR_D32N', 'colS_A106V', 'cprS_R241C', 'crrB_F84S', 'crrB_G183V', 'crrB_L94M', 'crrB_N141I', 'crrB_N141Y', 'crrB_P151L', 'crrB_P151S', 'crrB_Q10L', 'crrB_S195N', 'crrB_W140R', 'crrB_Y31H', 'cyaA_S352T', 'czcS_V194L', 'dacB_G437D', 'dacB_I356A', 'dacB_T428P', 'dacB_W459STOP', 'dfrB_A135T', 'dfrB_F99I', 'dfrB_F99S', 'dfrB_F99Y', 'dfrB_H150R', 'dfrB_H31N', 'dfrB_L21V', 'dfrB_L25I', 'dfrB_L41F', 'dfrB_N60I', 'dut_G91A', 'eat(A)_T450I', 'emrR_L113P', 'emrR_L64R', 'fabG_Y151V', 'fabI_F203A', 'fabI_F203C', 'fabI_F203L', 'fabI_F203V', 'fabI_G93A', 'fabI_G93S', 'fabI_G93V', 'fabI_M159T', 'folP_A184V', 'folP_E208K', 'folP_E258EKE', 'folP_F17L', 'folP_F25I', 'folP_F28I', 'folP_F28L', 'folP_P64A', 'folP_P64H', 'folP_P64L', 'folP_P64R', 'folP_P64S', 'folP_R228S', 'folP_S18L', 'folP_T51M', 'ftsI_A419G', 'ftsI_A454V', 'ftsI_A498T', 'ftsI_A515V', 'ftsI_F507L', 'ftsI_F533L', 'ftsI_G63S', 'ftsI_H394R', 'ftsI_I336IKYRI', 'ftsI_I336IPYRI', 'ftsI_L367Q', 'ftsI_L434V', 'ftsI_L461V', 'ftsI_N337NYRIN', 'ftsI_N427L', 'ftsI_N427S', 'ftsI_P527S', 'ftsI_Q458R', 'ftsI_Q475R', 'ftsI_R504C', 'ftsI_R504L', 'ftsI_S368L', 'ftsI_S538L', 'ftsI_T526S', 'ftsI_V471G', 'ftsI_V523A', 'ftsI_V523M', 'ftsI_Y367C', 'fusA1_A555E', 'fusA1_A595P', 'fusA1_E100G', 'fusA1 ...
# dict_keys(['pbp2', 'pbp2x', 'pbp1a', 'pbp2b', "aac(6')-Ie/aph(2'')-Ia", "aac(3)-Ib/aac(6')-Ib''", "aac(6')-30/aac(6')-Ib'", "ant(3'')-Ij/aac(6')-Ib", 'blaOXA/blaLRA13', "ant(3'')-Ih/aac(6')-IId", 'bla2', "aac(2')-IIa", "aac(2')-Ia", "aac(2')-Ib", "aac(2')-Ic", "aac(2')-Id", 'aac(3)-IIg', 'aac(3)-Ia', 'aac(3)-I', 'aac(3)-IIIa', 'aac(3)-IIIc', 'aac(3)-IIe', 'aac(3)-IIa', 'aac(3)-IId', 'aac(3)-IIb', 'aac(3)-IIc', 'aac(3)-IVa', 'aac(3)-IXa', 'aac(3)-Ib', 'aac(3)-VIII', 'aac(3)-VIIa', 'aac(3)-VIa', 'aac(3)-Xa', "aac(6')-31", "aac(6')-IIa", 'aacA40', "aac(6')-IIc", "aac(6')-Ia", "aac(6')-Iad", "aac(6')-Iak", "aac(6')-Ian", "aac(6')-Ib", "aac(6')-If", "aac(6')-Il", "aac(6')-Im", "aac(6')-Ip", "aac(6')-Iq", "aac(6')-Iz", 'aacA34', 'aacA37', 'aacA43', 'aad9', 'aadA1', 'aadA10', 'aadA11', 'aadA12', 'aadA13', 'aadA15', 'aadA16', 'aadA2', 'aadA21', 'aadA22', 'aadA25', 'aadA3', 'aadA4', 'aadA5', 'aadA6', 'aadA7', 'aadA8', 'aadA9', 'aadD1', 'aadE', 'aadK', 'aadS', 'ampC', 'blaSRT', "ant(2'')-Ia", "ant(4')-IIa", "ant(4')-IIb", 'aadD2', 'ant(6)-Ia', 'ant(6)-Ib', 'ant(9)-Ia', 'ant(9)-Ib', "aph(2'')-IIIa", "aph(2'')-IIa", "aph(2'')-IVa", "aph(2'')-Ie", "aph(2'')-If", "aph(2'')-Ig", "aph(2'')-Ih", "aph(3'')-Ia", "aph(3'')-Ib", "aph(3'')-Ic", "aph(3')-IIa", "aph(3')-IIIa", "aph(3')-IIb", 'aph(6)', "aph(3')-IIc", "aph(3')-IVa", "aph(3')-Ia", "aph(3')-Ib", "aph(3')-Id", "aph(3')-VIIIa", "aph(3')-VIIa", "aph(3')-VIa", "aph(3')-VIb", "aph(3')-Va", "aph(3')-Vb", "aph(3')-Vc", "aph(3')-XV", 'aph(4)-Ia', 'aph(6)-Ia', 'aph(6)-Ib', 'aph(6)-Ic', 'aph(6)-Id', "aph(7'')-Ia", 'aph(9)-Ia', 'aph(9)-Ib', 'apmA', 'armA', 'arr', 'bla2a', 'bla', 'blaLRA1', 'blaLRA5', 'blaA', 'blaC', 'blaE', 'blaF', 'blaI', 'blaL1', 'blaL2', 'blaLRA2', 'blaLRA3', 'blaLRA8', 'blaLRA9', 'blaLRA12', 'blaLRA17', 'blaLRA19', 'blaM', 'blaOCH', 'blaOKP-B', 'blaZ', 'blaR1', 'blaR39', 'blaS', 'blaSED', 'blaTHIN-B', 'ble', 'ble-Sh', 'bleO', 'blmB', 'car(A)', 'cat-TC', 'cat86', 'catA', 'catA1', 'catA13', 'catA15', 'catA16', 'catA2', 'catA3', 'catB', 'catB1', 'catB10', 'catB2', 'catB3', 'catB7', 'catB8', 'catB9', 'catD', 'catP', 'cblA', 'cepA', 'cepH', 'cepS', 'cfr', 'cfxA', 'cfxA2', 'cfxA3', 'cfxA4', 'cfxA5', 'chrB', 'cmlA1', 'cmlA4', 'cmlA5', 'cmlB', 'cmlB1', 'cmlR', 'cmlV', 'cmrA', 'cmx', 'cphA1', 'cpt', 'dfrA18', 'dfrA29', 'dfrA', 'dfrA1', 'dfrA10', 'dfrA12', 'dfrA14', 'dfrA15', 'dfrA16', 'dfrA17', 'dfrA20', 'dfrA21', 'dfrA22', 'dfrA33', 'dfrA23', 'dfrA24', 'dfrA25', 'dfrA26', 'dfrA27', 'dfrA3', 'dfrA30', 'dfrA31', 'dfrA32', 'dfrA3b', 'dfrA5', 'dfrA6', 'dfrA46', 'dfrA7', 'dfrA8', 'dfrA9', 'dfrB1', 'dfrB2', 'dfrB4', 'dfrD', 'dfrF', 'dfrG', 'dfrI', 'dfrB5', 'dfrK', 'ere(A)', 'ere(B)', 'ere(D)', 'erm(30)', 'erm(31)', 'erm(32)', 'erm(33)', 'erm(34)', 'erm(35)', 'erm(36)', 'erm(37)', 'erm(38)', 'erm(39)', 'erm(40)', 'erm(42)', 'erm(43)', 'erm(44)', 'erm(45)', 'erm(A)', 'erm(B)', 'erm(C)', 'erm(D)', 'erm(E)', 'erm(F)', 'erm(G)', 'erm(H)', 'erm(K)', 'erm(N)', 'erm(O)', 'erm(Q)', 'erm(S)', 'erm(T)', 'erm(U)', 'erm(V)', 'erm(W)', 'erm(X)', 'erm(Y)', 'erm(Z)', 'fexA', 'floR', 'floR2', 'fomA', 'fomB', 'fosA', 'fosB', 'fosC', 'fosC2', 'fosD', 'fosE', 'fosF', 'fosG', 'fosI', 'fosK', 'fosX', 'fusB', 'fusF', 'fusH', 'grm', 'hugA', 'iri', 'lnu(A)', 'lnu(AN2)', 'lnu(B)', 'lnu(C)', 'lnu(D)', 'lnu(F)', 'lnu(P)', 'lsa(A)', 'lsa(B)', 'lsa(C)', 'lsa(E)', 'mecA', 'mecA1', 'mecA2', 'mecB', 'mecC', 'mecI', 'mef(A)', 'mef(B)', 'mef(C)', 'mef(En2)', 'mgt', 'mph(A)', 'mph(B)', 'mph(C)', 'mph(E)', 'mph(F)', 'mph(G)', 'msr(A)', 'msr(C)', 'msr(D)', 'msr(E)', 'mupA', 'mupB', 'myrA', 'nimA', 'nimB', 'nimC', 'nimD', 'nimE', 'nimI', 'nimJ', 'npmA', 'nshR', 'ole(B)', 'oleD', 'oleI', 'optrA', 'oqxA', 'oqxB', 'otr(A)', 'otr(B)', 'blaPEN-bcc', 'blaPEN-I', 'blaPEN-M', 'blaPEN-L', 'blaPEN-J', 'pexA', 'qnrAS', 'qnrC', 'rgt', 'rmtA', 'rmtC', 'rmtG', 'rmtH', 'rph', 'sal(A)', 'sat2', 'sat3', 'sat4', 'spd', 'spw', 'srm(B)', 'sta', 'str', 'sul1', 'sul2', 'sul3', 'tcmA', 'tet(30)', 'tet(31)', 'tet(O/32/O)', 'tet(32)', 'tet(33)', 'tet(34) ...
# dict_keys(['1', 'aac(3)-VIIIa', "aac(6')-29a", "aac(6')-29b", "aac(6')-32", "aac(6')-33", "aac(6')-I30", "aac(6')-IIb", "aac(6')-Iae", "aac(6')-Iaf", "aac(6')-Iai", "aac(6')-Iaj", "aac(6')-Ial", "aac(6')-Ib-cr10", "aac(6')-Ib-cr11", "aac(6')-Ib-cr3", "aac(6')-Ib-cr4", "aac(6')-Ib-cr5", "aac(6')-Ib-cr6", "aac(6')-Ib-cr7", "aac(6')-Ib-cr8", "aac(6')-Ib-cr9", "aac(6')-Ib3", "aac(6')-Ib4", "aac(6')-Ic", "aac(6')-Ig", "aac(6')-Ih", "aac(6')-Ii", "aac(6')-Iid", "aac(6')-Iih", "aac(6')-Ij", "aac(6')-Ik", "aac(6')-Ir", "aac(6')-Is", "aac(6')-Isa", "aac(6')-It", "aac(6')-Iu", "aac(6')-Iv", "aac(6')-Iw", "aac(6')-Ix", 'aacA16', 'aacA35', 'aacA47', 'aacA56', 'aadA14', 'aadA17', 'ampC_Asob-1', 'ampC_Sliq-1', 'arr-2', 'arr-4', 'arr-5', 'arr-7', 'arr-8', 'blaAAK-1', 'blaACC-1', 'blaACC-1a', 'blaACC-1b', 'blaACC-1c', 'blaACC-1d', 'blaACC-2', 'blaACC-4', 'blaACC-7', 'blaACC-8', 'blaACI-1', 'blaACT-100', 'blaACT-101', 'blaACT-102', 'blaACT-103', 'blaACT-104', 'blaACT-105', 'blaACT-106', 'blaACT-107', 'blaACT-108', 'blaACT-109', 'blaACT-10', 'blaACT-110', 'blaACT-111', 'blaACT-112', 'blaACT-113', 'blaACT-114', 'blaACT-115', 'blaACT-116', 'blaACT-117', 'blaACT-118', 'blaACT-119', 'blaACT-120', 'blaACT-121', 'blaACT-122', 'blaACT-123', 'blaACT-124', 'blaACT-12', 'blaACT-13', 'blaACT-14', 'blaACT-15', 'blaACT-16', 'blaACT-17', 'blaACT-18', 'blaACT-19', 'blaACT-1', 'blaACT-20', 'blaACT-21', 'blaACT-22', 'blaACT-23', 'blaACT-24', 'blaACT-25', 'blaACT-27', 'blaACT-28', 'blaACT-29', 'blaACT-2', 'blaACT-30', 'blaACT-31', 'blaACT-32', 'blaACT-33', 'blaACT-34', 'blaACT-35', 'blaACT-36', 'blaACT-37', 'blaACT-38', 'blaACT-39', 'blaACT-3', 'blaACT-40', 'blaACT-41', 'blaACT-42', 'blaACT-43', 'blaACT-44', 'blaACT-45', 'blaACT-46', 'blaACT-47', 'blaACT-48', 'blaACT-49', 'blaACT-4', 'blaACT-50', 'blaACT-51', 'blaACT-52', 'blaACT-53', 'blaACT-54', 'blaACT-55', 'blaACT-56', 'blaACT-57', 'blaACT-58', 'blaACT-59', 'blaACT-5', 'blaACT-60', 'blaACT-61', 'blaACT-62', 'blaACT-63', 'blaACT-64', 'blaACT-65', 'blaACT-66', 'blaACT-67', 'blaACT-68', 'blaACT-69', 'blaACT-6', 'blaACT-70', 'blaACT-72', 'blaACT-73', 'blaACT-74', 'blaACT-75', 'blaACT-76', 'blaACT-77', 'blaACT-78', 'blaACT-79', 'blaACT-7', 'blaACT-80', 'blaACT-81', 'blaACT-82', 'blaACT-83', 'blaACT-84', 'blaACT-85', 'blaACT-86', 'blaACT-87', 'blaACT-88', 'blaACT-89', 'blaACT-8', 'blaACT-90', 'blaACT-91', 'blaACT-92', 'blaACT-93', 'blaACT-94', 'blaACT-95', 'blaACT-96', 'blaACT-97', 'blaACT-98', 'blaACT-99', 'blaACT-9', 'blaACT-GC1', 'blaADC-100', 'blaADC-101', 'blaADC-102', 'blaADC-103', 'blaADC-104', 'blaADC-105', 'blaADC-106', 'blaADC-107', 'blaADC-109', 'blaADC-10', 'blaADC-110', 'blaADC-112', 'blaADC-113', 'blaADC-114', 'blaADC-115', 'blaADC-116', 'blaADC-117', 'blaADC-119', 'blaADC-11', 'blaADC-120', 'blaADC-121', 'blaADC-122', 'blaADC-123', 'blaADC-125', 'blaADC-127', 'blaADC-128', 'blaADC-129', 'blaADC-12', 'blaADC-130', 'blaADC-131', 'blaADC-132', 'blaADC-133', 'blaADC-134', 'blaADC-135', 'blaADC-136', 'blaADC-137', 'blaADC-138', 'blaADC-139', 'blaADC-13', 'blaADC-140', 'blaADC-141', 'blaADC-143', 'blaADC-144', 'blaADC-145', 'blaADC-146', 'blaADC-147', 'blaADC-148', 'blaADC-149', 'blaADC-14', 'blaADC-150', 'blaADC-151', 'blaADC-152', 'blaADC-153', 'blaADC-154', 'blaADC-155', 'blaADC-156', 'blaADC-157', 'blaADC-158', 'blaADC-159', 'blaADC-15', 'blaADC-160', 'blaADC-162', 'blaADC-163', 'blaADC-164', 'blaADC-165', 'blaADC-166', 'blaADC-167', 'blaADC-168', 'blaADC-169', 'blaADC-16', 'blaADC-170', 'blaADC-171', 'blaADC-172', 'blaADC-173', 'blaADC-174', 'blaADC-175', 'blaADC-176', 'blaADC-177', 'blaADC-178', 'blaADC-179', 'blaADC-17', 'blaADC-180', 'blaADC-181', 'blaADC-182', 'blaADC-183', 'blaADC-184', 'blaADC-185', 'blaADC-186', 'blaADC-187', 'blaADC-188', 'blaADC-189', 'blaADC-18', 'blaADC-190', 'blaADC-191', 'blaADC-192', 'blaADC-193', 'blaADC-194', 'blaADC-195', 'blaADC-196', 'blaADC-197', 'blaADC-198', 'blaADC-199', 'blaADC-19', 'blaADC-1', 'blaADC-200', 'blaADC-201', 'blaADC-202', 'blaADC-203', 'blaADC-20 ...

# %%
unique_genotypes = gene_counts.index.tolist()
genotype_to_ab_class = {}
for g in unique_genotypes:
    if "aac(3)-II" in g: # aac(3)-II does not appear exactly in either the Allele or Gene family columns
                genotype_to_ab_class[g] = 'AMINOGLYCOSIDE'
    else:   
        if g.endswith('=POINT'):
            genotype_to_ab_class[g] = pm_to_ab_class[g.split('=')[0]]
        elif ('=PARTIAL' in g) or ('=HMM' in g) or ('=MISTRANSLATION' in g):
            genotype_to_ab_class[g] = gene_to_ab_class[g.split('=')[0]]
        else:
            try:
                genotype_to_ab_class[g] = gene_to_ab_class[g]
            except:
                genotype_to_ab_class[g] = gene_allele_to_ab_class[g]
print(genotype_to_ab_class)
# Out:
# {'glpT_E448K=POINT': 'FOSFOMYCIN', 'pmrB_E123D=POINT': 'COLISTIN', 'pmrB_Y358N=POINT': 'COLISTIN', 'blaTEM-1': 'BETA-LACTAM', 'tet(A)': 'TETRACYCLINE', 'sul2': 'SULFONAMIDE', "aph(3'')-Ib": 'AMINOGLYCOSIDE', 'uhpT_E350Q=POINT': 'FOSFOMYCIN', 'aph(6)-Id': 'AMINOGLYCOSIDE', 'gyrA_S83L=POINT': 'QUINOLONE', 'sul1': 'SULFONAMIDE', 'tet(B)': 'TETRACYCLINE', 'parC_S80I=POINT': 'QUINOLONE', 'cyaA_S352T=POINT': 'FOSMIDOMYCIN', 'gyrA_D87N=POINT': 'QUINOLONE', 'marR_S3N=POINT': 'MULTIDRUG', 'aadA1': 'AMINOGLYCOSIDE', 'mph(A)': 'MACROLIDE', 'dfrA17': 'TRIMETHOPRIM', 'ptsI_V25I=POINT': 'FOSFOMYCIN', 'aadA5': 'AMINOGLYCOSIDE', 'parE_I529L=POINT': 'QUINOLONE', 'blaCTX-M-15': 'BETA-LACTAM', 'parC_E84V=POINT': 'QUINOLONE', "aph(3')-Ia": 'AMINOGLYCOSIDE', 'aac(3)-IId': 'AMINOGLYCOSIDE', 'aadA2': 'AMINOGLYCOSIDE', 'blaCMY-2': 'BETA-LACTAM', 'aac(3)-VIa': 'AMINOGLYCOSIDE', 'blaOXA-1': 'BETA-LACTAM', 'floR': 'PHENICOL', 'dfrA1': 'TRIMETHOPRIM', "aac(6')-Ib-cr5": 'AMINOGLYCOSIDE/QUINOLONE', 'qnrS1': 'QUINOLONE', 'dfrA12': 'TRIMETHOPRIM', 'parE_S458A=POINT': 'QUINOLONE', 'sat2': 'STREPTOTHRICIN', 'aac(3)-IIe': 'AMINOGLYCOSIDE', 'catB3=PARTIAL_END_OF_CONTIG': 'PHENICOL', 'parE_L416F=POINT': 'QUINOLONE', 'blaHER-3': 'BETA-LACTAM', 'blaCTX-M-27': 'BETA-LACTAM', 'blaCTX-M-1': 'BETA-LACTAM', 'sul3': 'SULFONAMIDE', 'catA1': 'PHENICOL', 'dfrA14': 'TRIMETHOPRIM', 'parE_D475E=POINT': 'QUINOLONE', 'cmlA1': 'PHENICOL', 'aac(3)-IVa': 'AMINOGLYCOSIDE', 'aph(4)-Ia': 'AMINOGLYCOSIDE', 'blaCTX-M-55': 'BETA-LACTAM', 'tet(M)': 'TETRACYCLINE', 'blaTEM=PARTIAL_END_OF_CONTIG': 'BETA-LACTAM', 'ampC_C-42T=POINT': 'BETA-LACTAM', 'blaCTX-M-14': 'BETA-LACTAM', 'lnu(F)': 'LINCOSAMIDE', 'dfrA5': 'TRIMETHOPRIM', 'erm(B)': 'LINCOSAMIDE/MACROLIDE/STREPTOGRAMIN', 'ampC_T-32A=POINT': 'BETA-LACTAM', 'parE_I355T=POINT': 'QUINOLONE', 'parC_S57T=POINT': 'QUINOLONE', 'ble': 'BLEOMYCIN', 'tet(C)': 'TETRACYCLINE', 'blaSHV-12': 'BETA-LACTAM', 'qnrB19': 'QUINOLONE', 'dfrA7': 'TRIMETHOPRIM', 'parC_A56T=POINT': 'QUINOLONE', 'gyrA_D87Y=POINT': 'QUINOLONE', 'dfrA8': 'TRIMETHOPRIM', 'fosA7.5': 'FOSFOMYCIN', 'tet(D)': 'TETRACYCLINE', 'ftsI_N337NYRIN=POINT': 'BETA-LACTAM', 'parC_E84G=POINT': 'QUINOLONE', 'blaTEM': 'BETA-LACTAM', 'soxS_A12S=POINT': 'MULTIDRUG', 'nfsA_G126R=POINT': 'NITROFURAN', 'aadA22': 'AMINOGLYCOSIDE', 'nfsA_Q67STOP=POINT': 'NITROFURAN', 'aadA1=PARTIAL_END_OF_CONTIG': 'AMINOGLYCOSIDE', 'blaSHV-1': 'BETA-LACTAM', 'sul2=PARTIAL_END_OF_CONTIG': 'SULFONAMIDE', "ant(2'')-Ia": 'AMINOGLYCOSIDE', 'blaNDM-1': 'BETA-LACTAM', 'blaHER': 'BETA-LACTAM', 'qnrB4': 'QUINOLONE', 'blaDHA-1': 'BETA-LACTAM', 'mcr-1.1': 'COLISTIN', 'parE_E460D=POINT': 'QUINOLONE', 'mph(B)': 'MACROLIDE', 'catB3': 'PHENICOL', 'parE_S458T=POINT': 'QUINOLONE', 'catA2': 'PHENICOL', 'bleO': 'BLEOMYCIN', 'tet(A)=PARTIAL_END_OF_CONTIG': 'TETRACYCLINE', 'gyrA_S83A=POINT': 'QUINOLONE', 'ftsI_I336IKYRI=POINT': 'BETA-LACTAM', 'aadA2=PARTIAL_END_OF_CONTIG': 'AMINOGLYCOSIDE', "aph(3')-IIa": 'AMINOGLYCOSIDE', 'mef(B)': 'MACROLIDE', "aac(6')-Ib3": 'AMINOGLYCOSIDE', "aph(3'')-Ib=PARTIAL_END_OF_CONTIG": 'AMINOGLYCOSIDE', 'aph(6)-Id=PARTIAL_END_OF_CONTIG': 'AMINOGLYCOSIDE', 'blaCARB-2': 'BETA-LACTAM', 'blaTEM-52': 'BETA-LACTAM', 'blaCMY-42': 'BETA-LACTAM', 'blaCTX-M': 'BETA-LACTAM', 'gyrA_D87G=POINT': 'QUINOLONE/TRICLOSAN', 'blaCMY=PARTIAL_END_OF_CONTIG': 'BETA-LACTAM', 'fosA3': 'FOSFOMYCIN', 'blaNDM-5': 'BETA-LACTAM', 'parC_S80R=POINT': 'QUINOLONE', 'nfsA_Q113STOP=POINT': 'NITROFURAN', 'blaKPC-3': 'BETA-LACTAM', 'blaCMY-6': 'BETA-LACTAM', 'blaCTX-M-32': 'BETA-LACTAM', 'ompF_Q88STOP=POINT': 'BETA-LACTAM', 'blaCTX-M-8': 'BETA-LACTAM', 'blaCMY': 'BETA-LACTAM', 'pmrB_V161G=POINT': 'COLISTIN', 'nfsA_W159STOP=POINT': 'NITROFURAN', 'lnu(G)': 'LINCOSAMIDE', 'blaTEM-135': 'BETA-LACTAM', 'soxR_G121D=POINT': 'MULTIDRUG', 'rmtC': 'AMINOGLYCOSIDE', 'arr-3': 'RIFAMYCIN', "aac(6')-Ib": 'AMINOGLYCOSIDE', 'blaTEM-176': 'BETA-LACTAM', 'nfsA_H11Y=POINT': 'NITROFURAN', 'rmtB1': 'AMINOGLYCOSIDE', 'nfsB_F84S=POINT': 'NITROFURAN', 'sul1=PARTIAL_END_OF_CONTI ...

# %% [markdown]
# ### Filtering out isolates containing **beta-lactam** genes

# %%
filter_by = ['BETA-LACTAM']
num_before = ds_MM.shape[0]
ds_MM_filtered = ds_MM[ds_MM['genotypes'].apply(
                lambda x: not any(f in genotype_to_ab_class[gene] for f in filter_by for gene in x)
            )].reset_index(drop=True)
num_after = ds_MM_filtered.shape[0]
diff = num_before - num_after
print(f'Filtered out {diff} ({diff/num_before:.1%}) isolates. Now {num_after} isolates left.')
# Out:
# Filtered out 3106 (48.0%) isolates. Now 3362 isolates left.

# %% [markdown]
# How do the antibiotic distributions differ after the isolates are filtered?

# %%
ds_MM['num_R'] = ds_MM['phenotypes'].apply(lambda x: len([p for p in x if p.endswith('_R')]))
ds_MM['num_S'] = ds_MM['num_ab'] - ds_MM['num_R']
tot_R, tot_S = ds_MM['num_R'].sum(), ds_MM['num_S'].sum()
total_ab = ds_MM['num_ab'].sum()
print(f"Full dataset S/R share: {tot_S/total_ab:.1%}/{tot_R/total_ab:.1%}")

ds_MM_filtered['num_R'] = ds_MM_filtered['phenotypes'].apply(lambda x: len([p for p in x if p.endswith('_R')]))
ds_MM_filtered['num_S'] = ds_MM_filtered['num_ab'] - ds_MM_filtered['num_R']
tot_R, tot_S = ds_MM_filtered['num_R'].sum(), ds_MM_filtered['num_S'].sum()
total_ab = ds_MM_filtered['num_ab'].sum()
print(f"Filtered dataset S/R share: {tot_S/total_ab:.1%}/{tot_R/total_ab:.1%}")
# Out:
# Full dataset S/R share: 82.5%/17.5%
# Filtered dataset S/R share: 98.0%/2.0%

# %% [markdown]
# ## Results

# %% [markdown]
# ### Removing isolates containing any *bla* genes - Weighted loss

# %% [markdown]
# #### Antibiotic-level

# %%
model_names = ['No PT', 'Easy RPT', 'Medium RPT', 'Hard RPT', 'Easy CPT', 'Medium CPT', 'Hard CPT']
exp_folder = '2024-04-22_gene_iso'
train_params = '0_1known'
save_results = False
df_CV_ab = load_and_create_ab_df('WL_'+train_params, model_names=model_names, exp_folder=exp_folder)
df_CV_ab_no_bla = load_and_create_ab_df('WL_'+'no_bla_'+train_params, model_names=model_names, exp_folder=exp_folder)
beta_lactams = ['Penicillins', 'Cephalosporins', 'Carbapenems', 'Monobactams']
# Out:
# c:\Users\jespe\Documents\GitHub_local\ARFusion\utils.py:209: RuntimeWarning: Mean of empty slice
#   avg = np.nanmean(arr, axis=0)
# c:\Users\jespe\miniconda3\envs\ARFusion\Lib\site-packages\numpy\lib\nanfunctions.py:1872: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# c:\Users\jespe\Documents\GitHub_local\ARFusion\utils.py:209: RuntimeWarning: Mean of empty slice
#   avg = np.nanmean(arr, axis=0)
# c:\Users\jespe\miniconda3\envs\ARFusion\Lib\site-packages\numpy\lib\nanfunctions.py:1872: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# c:\Users\jespe\Documents\GitHub_local\ARFusion\utils.py:209: RuntimeWarning: Mean of empty slice
#   avg = np.nanmean(arr, axis=0)
# c:\Users\jespe\miniconda3\envs\ARFusion\Lib\site-packages\numpy\lib\nanfunctions.py:1872: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# c:\Users\jespe\Documents\GitHub_local\ARFusion\utils.py:209: RuntimeWarning: Mean of empty slice
#   avg = np.nanmean(arr, axis=0)
# c:\Users\jespe\miniconda3\envs\ARFusion\Lib\site-packages\numpy\lib\nanfunctions.py:1872: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# c:\Users\jespe\Documents\GitHub_local\ARFusion\utils.py:209: RuntimeWarning: Mean of empty slice
#   avg = np.nanmean(arr, axis=0)
# c:\Users\jespe\miniconda3\envs\ARFusion\Lib\site-packages\numpy\lib\nanfunctions.py:1872: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# c:\Users\jespe\Documents\GitHub_local\ARFusion\utils.py:209: RuntimeWarning: Mean of empty slice
#   avg = np.nanmean(arr, axis=0)
# c:\Users\jespe\miniconda3\envs\ARFusion\Lib\site-packages\numpy\lib\nanfunctions.py:1872: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,

# %% [markdown]
# #### Compare model-wise differences to measure resilience to loss of *bla* genes in training data

# %%
metrics = ['sensitivity', 'specificity', 'precision', 'F1', 'auc_score']
df_diff_ab = calculate_ab_level_differences(df_CV_ab, df_CV_ab_no_bla, metrics=metrics)
plot_ab_level_differences(df_diff_ab, 'F1')

# %%
plot_ab_level_differences(df_diff_ab, 'F1', ab_classes=beta_lactams)

# %%
plot_ab_level_differences(df_diff_ab, 'auc_score', ab_classes=beta_lactams)

# %%
plot_ab_level_differences(df_diff_ab, 'sensitivity', ab_classes=beta_lactams)

# %%
plot_ab_level_differences(df_diff_ab, 'specificity', ab_classes=beta_lactams)

# %%
plot_ab_level_differences(df_diff_ab, 'precision', ab_classes=beta_lactams)

# %% [markdown]
# #### Relative differences to model without PT for both presence and abscence of *bla* genes

# %%
df_CV, df_diff = load_and_create_abs_and_rel_diff_dfs('WL_'+train_params, model_names=model_names, exp_folder=exp_folder, include_auc=True)
df_CV_no_bla, df_diff_no_bla = load_and_create_abs_and_rel_diff_dfs('WL_'+'no_bla_'+train_params, model_names=model_names, exp_folder=exp_folder, include_auc=True)
# colors = ['slategray', 'forestgreen', 'gold', 'red']
colors = ['slategray', 'forestgreen', 'darkgreen', 'gold', 'darkgoldenrod', 'red', 'darkred']
drop_metrics = ['loss', 'accuracy']

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

ax1 = axes[0]  # Select the first subplot
df_diff.drop(drop_metrics).plot(kind='bar', y='avg', yerr='std', rot=0, ax=ax1, legend=False, capsize=2, ecolor='k', color=colors[1:])
ax1.set_xlabel('Metric')
ax1.set_ylabel('Difference')

ax2 = axes[1]  # Select the second subplot
df_CV.drop(drop_metrics).plot(kind='bar', y='avg', yerr='std', rot=0, ax=ax2, capsize=2, ecolor='k', color=colors)
noPT = Rectangle((0,0),1,1,fc='slategray', edgecolor='k', linewidth=0.5)
easyPT = Rectangle((0,0),1,1,fc='forestgreen', edgecolor='k', linewidth=0.5)
mediumPT = Rectangle((0,0),1,1,fc='gold', edgecolor='k', linewidth=0.5)
hardPT = Rectangle((0,0),1,1,fc='red', edgecolor='k', linewidth=0.5)
rpt = Rectangle((0,0),1,1,fc='lightgrey', edgecolor='k', linewidth=0.5)
cpt = Rectangle((0,0),1,1,fc='grey', edgecolor='k', linewidth=0.5)
ax1.legend(
    handles=[easyPT, mediumPT, hardPT, rpt, cpt],
    labels=['Easy', 'Medium', 'Hard', 'RPT', 'CPT'],
    ncols=2,
    framealpha=0,
)
ax2.legend(
    handles=[noPT],
    labels=['No PT'],
    ncols=1,
    framealpha=0,
)
ax2.set_ylim(0.25, 1)
ax2.set_xlabel('Metric')

fig.suptitle("FT, all genes, p=("+train_params.replace('_', ', ')+")")
fig.tight_layout()

savepath = os.path.join(BASE_DIR, 'results', 'figures', 'M_02_28', 'FT_diff.png')
plt.savefig(savepath, bbox_inches='tight', dpi=300, transparent=True) if save_results else None
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

ax1 = axes[0]  # Select the first subplot
df_diff_no_bla.drop(drop_metrics).plot(kind='bar', y='avg', yerr='std', rot=0, ax=ax1, legend=False, capsize=2, ecolor='k', color=colors[1:])
ax1.set_xlabel('Metric')
ax1.set_ylabel('Difference')

ax2 = axes[1]  # Select the second subplot
df_CV_no_bla.drop(drop_metrics).plot(kind='bar', y='avg', yerr='std', rot=0, ax=ax2, capsize=2, ecolor='k', color=colors)
noPT = Rectangle((0,0),1,1,fc='slategray', edgecolor='k', linewidth=0.5)
easyPT = Rectangle((0,0),1,1,fc='forestgreen', edgecolor='k', linewidth=0.5)
mediumPT = Rectangle((0,0),1,1,fc='gold', edgecolor='k', linewidth=0.5)
hardPT = Rectangle((0,0),1,1,fc='red', edgecolor='k', linewidth=0.5)
rpt = Rectangle((0,0),1,1,fc='lightgrey', edgecolor='k', linewidth=0.5)
cpt = Rectangle((0,0),1,1,fc='grey', edgecolor='k', linewidth=0.5)
ax1.legend(
    handles=[easyPT, mediumPT, hardPT, rpt, cpt],
    labels=['Easy', 'Medium', 'Hard', 'RPT', 'CPT'],
    ncols=2,
    framealpha=0,
)
ax2.legend(
    handles=[noPT],
    labels=['No PT'],
    ncols=1,
    framealpha=0,
)
ax2.set_ylim(0.25, 1)
ax2.set_xlabel('Metric')

fig.suptitle("FT, filtered dataset, p=("+train_params.replace('_', ', ')+")")
fig.tight_layout()

savepath = os.path.join(BASE_DIR, 'results', 'figures', 'M_02_28', 'FT_diff.png')
plt.savefig(savepath, bbox_inches='tight', dpi=300, transparent=True) if save_results else None
plt.show()

# %% [markdown]
# #### Isolate-level

# %%
def get_stats_by_group(df, group_col):
    df_stats = df.groupby(group_col).agg({
        'genotypes': 'count',
        'num_genotypes': ['mean', 'std'],
        'num_ab': ['mean', 'std'],
        'num_masked_ab': 'sum',
        'num_correct': 'sum',
        'num_masked_S': 'sum',
        'correct_S': 'sum',
        'num_masked_R': 'sum',
        'correct_R': 'sum',
        'all_correct': 'mean',
    })
    df_stats.rename(columns={'all_correct': 'isolate accuracy'}, inplace=True)
    df_stats['specificity'] = df_stats['correct_S'] / df_stats['num_masked_S']
    df_stats['sensitivity'] = df_stats['correct_R'] / df_stats['num_masked_R']
    df_stats['accuracy'] = df_stats['num_correct'] / df_stats['num_masked_ab']
    df_stats.drop(['num_masked_ab', 'num_correct', 'num_masked_S', 'correct_S', 'num_masked_R', 'correct_R'], axis=1, inplace=True)
    return df_stats

# %%
# abbr_to_class = config['data']['antibiotics']['abbr_to_class']
# containing_bla['num_bla_ab_masked'] = containing_bla['masked_ab'].apply(lambda x: len([ab for ab in x if abbr_to_class[ab.split('_')[0]] in beta_lactams]))
# containing_bla['num_R_bla_ab_masked'] = containing_bla['masked_ab'].apply(lambda x: len([ab for ab in x if abbr_to_class[ab.split('_')[0]] in beta_lactams and ab.split('_')[1] == 'R']))
# res_df = get_stats_by_group(containing_bla, 'num_bla_ab_masked')
# res_df

# %%
# res_df = get_stats_by_group(containing_bla, 'num_R_bla_ab_masked')
# res_df

# %% [markdown]
# ### Removing isolates containing any *bla* genes

# %%
model_names = ['No PT', 'Easy RPT', 'Medium RPT', 'Hard RPT', 'Easy CPT', 'Medium CPT', 'Hard CPT']
exp_folder = '2024-04-22_gene_iso'
train_params = '0_1known'
save_results = False
df_CV_ab = load_and_create_ab_df(train_params, model_names=model_names, exp_folder=exp_folder, include_auc=False)
df_CV_ab_no_bla = load_and_create_ab_df('no_bla_'+train_params, model_names=model_names, exp_folder=exp_folder, include_auc=False)
beta_lactams = ['Penicillins', 'Cephalosporins', 'Carbapenems', 'Monobactams']
# Out:
# c:\Users\jespe\Documents\GitHub_local\ARFusion\utils.py:209: RuntimeWarning: Mean of empty slice
#   avg = np.nanmean(arr, axis=0)
# c:\Users\jespe\miniconda3\envs\ARFusion\Lib\site-packages\numpy\lib\nanfunctions.py:1872: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# c:\Users\jespe\Documents\GitHub_local\ARFusion\utils.py:209: RuntimeWarning: Mean of empty slice
#   avg = np.nanmean(arr, axis=0)
# c:\Users\jespe\miniconda3\envs\ARFusion\Lib\site-packages\numpy\lib\nanfunctions.py:1872: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# c:\Users\jespe\Documents\GitHub_local\ARFusion\utils.py:209: RuntimeWarning: Mean of empty slice
#   avg = np.nanmean(arr, axis=0)
# c:\Users\jespe\miniconda3\envs\ARFusion\Lib\site-packages\numpy\lib\nanfunctions.py:1872: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# c:\Users\jespe\Documents\GitHub_local\ARFusion\utils.py:209: RuntimeWarning: Mean of empty slice
#   avg = np.nanmean(arr, axis=0)
# c:\Users\jespe\miniconda3\envs\ARFusion\Lib\site-packages\numpy\lib\nanfunctions.py:1872: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# c:\Users\jespe\Documents\GitHub_local\ARFusion\utils.py:209: RuntimeWarning: Mean of empty slice
#   avg = np.nanmean(arr, axis=0)
# c:\Users\jespe\miniconda3\envs\ARFusion\Lib\site-packages\numpy\lib\nanfunctions.py:1872: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# c:\Users\jespe\Documents\GitHub_local\ARFusion\utils.py:209: RuntimeWarning: Mean of empty slice
#   avg = np.nanmean(arr, axis=0)
# c:\Users\jespe\miniconda3\envs\ARFusion\Lib\site-packages\numpy\lib\nanfunctions.py:1872: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# c:\Users\jespe\Documents\GitHub_local\ARFusion\utils.py:209: RuntimeWarning: Mean of empty slice
#   avg = np.nanmean(arr, axis=0)
# c:\Users\jespe\miniconda3\envs\ARFusion\Lib\site-packages\numpy\lib\nanfunctions.py:1872: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,

# %% [markdown]
# #### Compare model-wise differences to measure resilience to loss of *bla* genes in training data

# %%
metrics = ['sensitivity', 'specificity', 'precision', 'F1']
df_diff_ab = calculate_ab_level_differences(df_CV_ab, df_CV_ab_no_bla, metrics=metrics)
plot_ab_level_differences(df_diff_ab, 'F1')

# %%
plot_ab_level_differences(df_diff_ab, 'F1', ab_classes=beta_lactams)

# %%
plot_ab_level_differences(df_diff_ab, 'sensitivity', ab_classes=beta_lactams)

# %%
plot_ab_level_differences(df_diff_ab, 'specificity', ab_classes=beta_lactams)

# %%
plot_ab_level_differences(df_diff_ab, 'precision', ab_classes=beta_lactams)

# %% [markdown]
# #### Relative differences to model without PT for both presence and abscence of *bla* genes

# %%
df_CV, df_diff = load_and_create_abs_and_rel_diff_dfs(train_params, model_names=model_names, exp_folder=exp_folder, include_auc=False)
df_CV_no_bla, df_diff_no_bla = load_and_create_abs_and_rel_diff_dfs('no_bla_'+train_params, model_names=model_names, exp_folder=exp_folder, include_auc=False)
# colors = ['slategray', 'forestgreen', 'gold', 'red']
colors = ['slategray', 'forestgreen', 'darkgreen', 'gold', 'darkgoldenrod', 'red', 'darkred']
drop_metrics = ['loss', 'accuracy']

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

ax1 = axes[0]  # Select the first subplot
df_diff.drop(drop_metrics).plot(kind='bar', y='avg', yerr='std', rot=0, ax=ax1, legend=False, capsize=2, ecolor='k', color=colors[1:])
ax1.set_xlabel('Metric')
ax1.set_ylabel('Difference')

ax2 = axes[1]  # Select the second subplot
df_CV.drop(drop_metrics).plot(kind='bar', y='avg', yerr='std', rot=0, ax=ax2, capsize=2, ecolor='k', color=colors)
noPT = Rectangle((0,0),1,1,fc='slategray', edgecolor='k', linewidth=0.5)
easyPT = Rectangle((0,0),1,1,fc='forestgreen', edgecolor='k', linewidth=0.5)
mediumPT = Rectangle((0,0),1,1,fc='gold', edgecolor='k', linewidth=0.5)
hardPT = Rectangle((0,0),1,1,fc='red', edgecolor='k', linewidth=0.5)
rpt = Rectangle((0,0),1,1,fc='lightgrey', edgecolor='k', linewidth=0.5)
cpt = Rectangle((0,0),1,1,fc='grey', edgecolor='k', linewidth=0.5)
ax1.legend(
    handles=[easyPT, mediumPT, hardPT, rpt, cpt],
    labels=['Easy', 'Medium', 'Hard', 'RPT', 'CPT'],
    ncols=2,
    framealpha=0,
)
ax2.legend(
    handles=[noPT],
    labels=['No PT'],
    ncols=1,
    framealpha=0,
)
ax2.set_ylim(0.2, 1)
ax2.set_xlabel('Metric')

fig.suptitle("FT, all genes, p=("+train_params.replace('_', ', ')+")")
fig.tight_layout()

savepath = os.path.join(BASE_DIR, 'results', 'figures', 'M_02_28', 'FT_diff.png')
plt.savefig(savepath, bbox_inches='tight', dpi=300, transparent=True) if save_results else None
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

ax1 = axes[0]  # Select the first subplot
df_diff_no_bla.drop(drop_metrics).plot(kind='bar', y='avg', yerr='std', rot=0, ax=ax1, legend=False, capsize=2, ecolor='k', color=colors[1:])
ax1.set_xlabel('Metric')
ax1.set_ylabel('Difference')

ax2 = axes[1]  # Select the second subplot
df_CV_no_bla.drop(drop_metrics).plot(kind='bar', y='avg', yerr='std', rot=0, ax=ax2, capsize=2, ecolor='k', color=colors)
noPT = Rectangle((0,0),1,1,fc='slategray', edgecolor='k', linewidth=0.5)
easyPT = Rectangle((0,0),1,1,fc='forestgreen', edgecolor='k', linewidth=0.5)
mediumPT = Rectangle((0,0),1,1,fc='gold', edgecolor='k', linewidth=0.5)
hardPT = Rectangle((0,0),1,1,fc='red', edgecolor='k', linewidth=0.5)
rpt = Rectangle((0,0),1,1,fc='lightgrey', edgecolor='k', linewidth=0.5)
cpt = Rectangle((0,0),1,1,fc='grey', edgecolor='k', linewidth=0.5)
ax1.legend(
    handles=[easyPT, mediumPT, hardPT, rpt, cpt],
    labels=['Easy', 'Medium', 'Hard', 'RPT', 'CPT'],
    ncols=2,
    framealpha=0,
)
ax2.legend(
    handles=[noPT],
    labels=['No PT'],
    ncols=1,
    framealpha=0,
)
ax2.set_ylim(0.2, 1)
ax2.set_xlabel('Metric')

fig.suptitle("FT, filtered dataset, p=("+train_params.replace('_', ', ')+")")
fig.tight_layout()

savepath = os.path.join(BASE_DIR, 'results', 'figures', 'M_02_28', 'FT_diff.png')
plt.savefig(savepath, bbox_inches='tight', dpi=300, transparent=True) if save_results else None
plt.show()
